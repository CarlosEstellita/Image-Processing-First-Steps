# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosEstellita/Image-Processing-First-Steps/blob/main/Image-Processing-First-Steps/Medical%20Images%20-%20Thresholding/B%C3%A1sicoDoB%C3%A1sico_Threshold_pt1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Básico do Básico - Segmentação de imagens com limiarização (pt. 1)

# %% [markdown]
# #Threshold: Ultrassom de mama - imagem 1, tumor benígno

# %% [markdown]
# ###Importando as bibliotecas

# %%
# %matplotlib inline
import matplotlib.pyplot as plt #para plotar as imagens
import matplotlib.image as mpimg #para importar as imagens
import skimage.io #também para plotar imagens
import numpy as np #para trabalhar com as imagens
import sys
from skimage.filters import threshold_otsu #função que faz limiarização
from skimage.color import rgb2gray #função que converte imagens em RGB para escala de cinzas
from skimage import exposure #exposição

# %% [markdown]
# ###Importando a imagem

# %%
img_mama1 = mpimg.imread('benign (1).png')

# %% [markdown]
# ###Plotando a imagem

# %%
skimage.io.imshow(img_mama1) # ou imgplot = plt.imshow(img_mama1)

# %% [markdown]
# ###Convertendo a imagem para escala de cinza e definindo o limiar pela função de Otsu

# %%
img_mama1_gray = rgb2gray(img_mama1)
thresh = threshold_otsu(img_mama1_gray)
binary = img_mama1_gray > thresh

# %% [markdown]
# ###Imagem final plotada

# %%
skimage.io.imshow(binary) # ou imgplot = plt.imshow(binary)

# %% [markdown]
# ###Plotando imagem em escala de cinzas e seu histograma

# %%
skimage.io.imshow(img_mama1_gray)
histogram, bin_edges = np.histogram(img_mama1_gray, bins=256, range=(0, 1))
plt.figure()
plt.title("Histograma da escala de cinzas")
plt.xlabel("Intensidade do pixel")
plt.ylabel("Número de pixels")
plt.xlim([0.0, 1.0])

plt.plot(bin_edges[0:-1], histogram)
plt.show()

# %% [markdown]
# ###Equalizando a imagem original

# %%
img_equalized1 = exposure.equalize_hist(img_mama1)
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/exposure/exposure.py:181: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   hist, bin_centers = histogram(image, nbins)

# %% [markdown]
# ###Plotando duas imagens: a original e sua versão equalizada

# %%
skimage.io.imshow(img_mama1) # ou imgplot = plt.imshow(img_mama1)

# %%
skimage.io.imshow(img_equalized1) # ou imgplot = plt.imshow(img_equalized1)

# %% [markdown]
# ###Com a versão equalizada, transforma-la em escala de cinzas e definindo seu novo limiar

# %%
img_mama1_gray_equalized = rgb2gray(img_equalized1)
thresh = threshold_otsu(img_mama1_gray_equalized)
binary4 = img_mama1_gray_equalized > thresh

# %% [markdown]
# ###Plotando duas imagens: a limiarização normal e da imagem equalizada

# %%
skimage.io.imshow(binary) # ou imgplot = plt.imshow(binary)

# %%
skimage.io.imshow(binary4) # ou imgplot = plt.imshow(binary4)

# %% [markdown]
# ###Plotando a imagem equalizada em escala de cinzas e seu histograma

# %%
skimage.io.imshow(img_mama1_gray_equalized)
histogram, bin_edges = np.histogram(img_mama1_gray_equalized, bins=256, range=(0, 1))
plt.figure()
plt.title("Histograma da escala de cinzas (equalizada)")
plt.xlabel("Intensidade do pixel")
plt.ylabel("Número de pixels")
plt.xlim([0.0, 1.0])

plt.plot(bin_edges[0:-1], histogram)
plt.show()

# %% [markdown]
# ###Fazendo a equalização adaptativa da imagem original

# %%
img_adpt_equalized1 = exposure.equalize_adapthist(img_mama1)

# %% [markdown]
# ###Plotando as duas imagens: a original e a CLAHE

# %%
skimage.io.imshow(img_mama1) # ou imgplot = plt.imshow(img_mama1)

# %%
skimage.io.imshow(img_adpt_equalized1) # ou imgplot = plt.imshow(img_adpt_equalized1)

# %% [markdown]
# ###Com a CLAHE, transforma-la em escala de cinzas e definindo seu novo limiar

# %%
img_mama1_gray_adpt_equalized = rgb2gray(img_adpt_equalized1)
thresh = threshold_otsu(img_mama1_gray_adpt_equalized)
binary7 = img_mama1_gray_adpt_equalized > thresh

# %% [markdown]
# ###Plotando duas imagens, limirarização normal e a CLAHE

# %%
skimage.io.imshow(binary) # ou imgplot = plt.imshow(binary)

# %%
skimage.io.imshow(binary7) # ou imgplot = plt.imshow(binary7)

# %% [markdown]
# ###Plotando a CLAHE em escala de cinzas e seu histograma

# %%
skimage.io.imshow(img_mama1_gray_adpt_equalized)
histogram, bin_edges = np.histogram(img_mama1_gray_adpt_equalized, bins=256, range=(0, 1))
plt.figure()
plt.title("Histograma da escala de cinzas (CLAHE)")
plt.xlabel("Intensidade do pixel")
plt.ylabel("Número de pixels")
plt.xlim([0.0, 1.0])

plt.plot(bin_edges[0:-1], histogram)
plt.show()

# %% [markdown]
# #Threshold: Ultrassom de mama - imagem 1, tumor malígno

# %% [markdown]
# ###Importando a imagem

# %%
img_mama2 = mpimg.imread('malignant (1).png')

# %% [markdown]
# ###Plotando a imagem

# %%
skimage.io.imshow(img_mama2) # ou imgplot = plt.imshow(img_mama2)

# %% [markdown]
# ###Convertendo a imagem para escala de cinza e definindo o limiar pela função de Otsu

# %%
img_mama2_gray = rgb2gray(img_mama2)
thresh = threshold_otsu(img_mama2_gray)
binary2 = img_mama2_gray > thresh

# %% [markdown]
# ###Imagem final plotada

# %%
skimage.io.imshow(binary2) # ou imgplot = plt.imshow(binary2)

# %% [markdown]
# ###Plotando a imagem original em escala de cinzas e seu histograma

# %%
skimage.io.imshow(img_mama2_gray)
histogram, bin_edges = np.histogram(img_mama2_gray, bins=256, range=(0, 1))
plt.figure()
plt.title("Histograma da escala de cinzas")
plt.xlabel("Intensidade do pixel")
plt.ylabel("Número de pixels")
plt.xlim([0.0, 1.0])

plt.plot(bin_edges[0:-1], histogram)
plt.show()

# %% [markdown]
# ###Equalizando a imagem original

# %%
img_equalized2 = exposure.equalize_hist(img_mama2)
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/exposure/exposure.py:181: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   hist, bin_centers = histogram(image, nbins)

# %% [markdown]
# ###Plotando duas imagens: a original e sua versão equalizada

# %%
skimage.io.imshow(img_mama2) # ou imgplot = plt.imshow(img_mama2)

# %%
skimage.io.imshow(img_equalized2) # ou imgplot = plt.imshow(img_equalized2)

# %% [markdown]
# ###Com a versão equalizada, transforma-la em escala de cinzas e definindo seu novo limiar

# %%
img_mama2_gray_equalized = rgb2gray(img_equalized2)
thresh = threshold_otsu(img_mama2_gray_equalized)
binary3 = img_mama2_gray_equalized > thresh

# %% [markdown]
# ###Plotando duas imagens: a limiarização normal e da imagem equalizada

# %%
skimage.io.imshow(binary2) # ou imgplot = plt.imshow(binary2)

# %%
skimage.io.imshow(binary3) # ou imgplot = plt.imshow(binary3)

# %% [markdown]
# ###Plotando a imagem equalizada em escala de cinzas e seu histograma

# %%
skimage.io.imshow(img_mama2_gray_equalized)
histogram, bin_edges = np.histogram(img_mama2_gray_equalized, bins=256, range=(0, 1))
plt.figure()
plt.title("Histograma da escala de cinzas (equalizada)")
plt.xlabel("Intensidade do pixel")
plt.ylabel("Número de pixels")
plt.xlim([0.0, 1.0])

plt.plot(bin_edges[0:-1], histogram)
plt.show()

# %% [markdown]
# ###Fazendo a equalização adaptativa da imagem original

# %%
img_adpt_equalized3 = exposure.equalize_adapthist(img_mama2)

# %% [markdown]
# ###Plotando duas imagens: a original e a CLAHE

# %%
skimage.io.imshow(img_mama2) # ou imgplot = plt.imshow(img_mama2)

# %%
skimage.io.imshow(img_adpt_equalized3) # ou imgplot = plt.imshow(img_adpt_equalized3)

# %% [markdown]
# ###Com a CLAHE, transforma-la em escala de cinzas e definir seu novo limiar

# %%
img_mama2_gray_adpt_equalized = rgb2gray(img_adpt_equalized3)
thresh = threshold_otsu(img_mama2_gray_adpt_equalized)
binary8 = img_mama2_gray_adpt_equalized > thresh

# %% [markdown]
# ###Plotando duas imagens: limiarização normal e da CLAHE

# %%
skimage.io.imshow(binary2) # ou imgplot = plt.imshow(binary2)

# %%
skimage.io.imshow(binary8) # ou imgplot = plt.imshow(binary8)

# %% [markdown]
# ###Plotando a CLAHE em escala de cinzas e seu histograma

# %%
skimage.io.imshow(img_mama2_gray_adpt_equalized)
histogram, bin_edges = np.histogram(img_mama2_gray_adpt_equalized, bins=256, range=(0, 1))
plt.figure()
plt.title("Histograma da escala de cinzas (CLAHE)")
plt.xlabel("Intensidade do pixel")
plt.ylabel("Número de pixels")
plt.xlim([0.0, 1.0])

plt.plot(bin_edges[0:-1], histogram)
plt.show()

# %% [markdown]
# #Threshold: Imagem digital de retina - imagem 1, treino

# %% [markdown]
# ###Importando a imagem

# %%
img_retina = mpimg.imread('01_test.tif')

# %% [markdown]
# ###Plotando a imagem

# %%
skimage.io.imshow(img_retina) # ou imgplot = plt.imshow(img_retina)

# %% [markdown]
# ###Convertendo a imagem para escala de cinza e definindo o limiar pela função de Otsu

# %%
img_retina_gray = rgb2gray(img_retina)
thresh = threshold_otsu(img_retina_gray)
binary5 = img_retina_gray > thresh

# %% [markdown]
# ###Imagem final plotada

# %%
skimage.io.imshow(binary5) # ou imgplot = plt.imshow(binary5)

# %% [markdown]
# ###Plotando a imagem original e seu histograma

# %%
skimage.io.imshow(img_retina)
histogram, bin_edges = np.histogram(img_retina_gray, bins=256, range=(0, 1))
plt.figure()
plt.title("Histograma")
plt.xlabel("Intensidade do pixel")
plt.ylabel("Número de pixels")
plt.xlim([0.0, 1.0])

plt.plot(bin_edges[0:-1], histogram)
plt.show()

# %% [markdown]
# ###Plotando imagem em escala de cinzas e seu histograma

# %%
skimage.io.imshow(img_retina_gray)
histogram, bin_edges = np.histogram(img_retina_gray, bins=256, range=(0, 1))
plt.figure()
plt.title("Histograma da escala de cinzas")
plt.xlabel("Intensidade do pixel")
plt.ylabel("Número de pixels")
plt.xlim([0.0, 1.0])

plt.plot(bin_edges[0:-1], histogram)
plt.show()

# %% [markdown]
# ###Equalizando a imagem original

# %%
img_equalized3 = exposure.equalize_hist(img_retina)
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/exposure/exposure.py:181: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   hist, bin_centers = histogram(image, nbins)

# %% [markdown]
# ###Plotando duas imagens: a original e sua versão equalizada

# %%
skimage.io.imshow(img_retina) # ou imgplot = plt.imshow(img_retina)

# %%
skimage.io.imshow(img_equalized3) # ou imgplot = plt.imshow(img_equalized3)

# %% [markdown]
# ###Com a versão equalizada, transforma-la em escala de cinzas e definindo seu novo limiar

# %%
img_retina_gray_equalized = rgb2gray(img_equalized3)
thresh = threshold_otsu(img_retina_gray_equalized)
binary6 = img_retina_gray_equalized > thresh

# %% [markdown]
# ###Plotando duas imagens: a limiarização normal e da imagem equalizada

# %%
skimage.io.imshow(binary5) # ou imgplot = plt.imshow(binary5)

# %%
skimage.io.imshow(binary6) # ou imgplot = plt.imshow(binary6)

# %% [markdown]
# ###Plotando a imagem equalizada e seu histograma

# %%
skimage.io.imshow(img_equalized3)
histogram, bin_edges = np.histogram(img_retina_gray, bins=256, range=(0, 1))
plt.figure()
plt.title("Histograma")
plt.xlabel("Intensidade do pixel")
plt.ylabel("Número de pixels")
plt.xlim([0.0, 1.0])

plt.plot(bin_edges[0:-1], histogram)
plt.show()

# %% [markdown]
# ###Plotando a imagem equalizada em escala de cinzas e seu histograma

# %%
skimage.io.imshow(img_retina_gray_equalized)
histogram, bin_edges = np.histogram(img_retina_gray_equalized, bins=256, range=(0, 1))
plt.figure()
plt.title("Histograma da escala de cinzas (equalizada)")
plt.xlabel("Intensidade do pixel")
plt.ylabel("Número de pixels")
plt.xlim([0.0, 1.0])

plt.plot(bin_edges[0:-1], histogram)
plt.show()

# %% [markdown]
# ###Fazendo a equalização adaptativa da imagem original

# %%
img_adpt_equalized2 = exposure.equalize_adapthist(img_retina)

# %% [markdown]
# ###Plotando duas imagens: a original e a CLAHE

# %%
skimage.io.imshow(img_retina) # ou imgplot = plt.imshow(img_retina)

# %%
skimage.io.imshow(img_adpt_equalized2) # ou imgplot = plt.imshow(img_adpt_equalized2)

# %% [markdown]
# ###Com a CLAHE, transforma-la em escala de cinzas e definir seu novo limiar

# %%
img_retina_gray_adpt_equalized = rgb2gray(img_adpt_equalized2)
thresh = threshold_otsu(img_retina_gray_adpt_equalized)
binary9 = img_retina_gray_adpt_equalized > thresh

# %% [markdown]
# ###Plotando duas imagens: limiarização normal e a CLAHE

# %%
skimage.io.imshow(binary5) # ou imgplot = plt.imshow(binary5)

# %%
skimage.io.imshow(binary9) # ou imgplot = plt.imshow(binary9)

# %% [markdown]
# ###Plotando imagem original CLAHE

# %%
skimage.io.imshow(img_adpt_equalized2)
histogram, bin_edges = np.histogram(img_retina_gray, bins=256, range=(0, 1))
plt.figure()
plt.title("Histograma")
plt.xlabel("Intensidade do pixel")
plt.ylabel("Número de pixels")
plt.xlim([0.0, 1.0])

plt.plot(bin_edges[0:-1], histogram)
plt.show()

# %% [markdown]
# ###Plotando a CLAHE em escala de cinzas e seu histograma

# %%
skimage.io.imshow(img_retina_gray_adpt_equalized)
histogram, bin_edges = np.histogram(img_retina_gray_adpt_equalized, bins=256, range=(0, 1))
plt.figure()
plt.title("Histograma da escala de cinzas (CLAHE)")
plt.xlabel("Intensidade do pixel")
plt.ylabel("Número de pixels")
plt.xlim([0.0, 1.0])

plt.plot(bin_edges[0:-1], histogram)
plt.show()
